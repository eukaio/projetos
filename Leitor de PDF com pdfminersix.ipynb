# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import StringIO

def convert_pdf_to_txt(path):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = open(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos=set()

    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True):
        interpreter.process_page(page)

    text = retstr.getvalue()

    fp.close()
    device.close()
    retstr.close()
    return text

convert_pdf_to_txt(r'C:\Users\kainu\Downloads\teste.pdf')

# %%
import io
import csv

from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from csv import writer

def convert_pdf_to_txt(path):
    rsrcmgr = PDFResourceManager()
    retstr = io.StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = open(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos = set()

    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages,
                                  password=password,
                                  caching=caching,
                                  check_extractable=False):
        interpreter.process_page(page)



    fp.close()
    device.close()
    text = retstr.getvalue()
    retstr.close()
    return text

reds = convert_pdf_to_txt(r'C:\Users\kainu\Downloads\2022-009200654-001.pdf').splitlines()

i=0
for campo in reds:
    print(i,"---->",reds[i],"\n")
    i = i+1
    
    
with open('./BD.csv','a', newline='') as csvfile:
    writer = csv.writer(csvfile, delimiter='|')
    writer.writerow([reds[2][3:21],#número do reds 
                     reds[70][1:10],#data do fato
                     reds[70][13:18],#horário do fato
                     reds[58],#Nat principal
                     reds[62][1:],#tentado/consumado
                     reds[148],#meio utilizado
                     reds[60],#alvo do evento
                     reds[78][1:],#município
                     reds[74][1:],#logradouro
                     reds[76],#número
                     reds[113][1:],#bairro
                     reds[124],#Latitude Graus
                     reds[127],#Latitude Minutos
                     reds[131],#Latitude Segundos
                     reds[136],#Longitude Graus
                     reds[139],#Longitude Minutos
                     reds[143]#Longitude Segundos
                    ])
    csvfile.close()
# Out:
# C:\Users\kainu\AppData\Local\Programs\Python\Python39\lib\site-packages\pdfminer\pdfpage.py:159: PDFTextExtractionNotAllowedWarning: The PDF <_io.BufferedReader name='C:\\Users\\kainu\\Downloads\\2022-009200654-001.pdf'> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding.
#   warnings.warn(warning_msg, PDFTextExtractionNotAllowedWarning)
# 0 ----> SISTEMA INTEGRADO DE DEFESA SOCIAL -  POLICIA MILITAR
#
# 1 ---->
#
# 2 ----> Nº 2022-009200654-001
#
# 3 ---->
#
# 4 ----> 29
#
# 5 ---->
#
# 6 ----> BOLETIM DE OCORRÊNCIA
#
# 7 ---->
#
# 8 ---->   BO NÚMERO
#
# 9 ---->
#
# 10 ---->   XXXX
#
# 11 ---->
#
# 12 ----> Fl.
#
# 13 ---->
#
# 14 ----> 1/12
#
# 15 ---->
#
# 16 ---->   UNIDADE RESPONSÁVEL PELO REGISTRO
#
# 17 ---->  86 CIA PM/15 BPM/10 RPM
#
# 18 ---->  UNIDADE DE ÀREA RESPONSÁVEL
#
# 19 ---->
#
# 20 ---->   MUNICÍPIO
#
# 21 ----> PATOS DE MINAS
#
# 22 ---->
#
# 23 ---->  UNIDADE MILITAR:
#
# 24 ---->
#
# ...

# %%
reds[78][1:]
# Out:
# 'PATOS DE MINAS'
