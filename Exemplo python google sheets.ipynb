# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials


# use creds to create a client to interact with the Google Drive API
scope = ['https://spreadsheets.google.com/feeds']
creds = ServiceAccountCredentials.from_json_keyfile_name('credentials.json', scope)
client = gspread.authorize(creds)

# Find a workbook by name and open the first sheet
# Make sure you use the right name here.
sheet = client.open("Copy of Legislators 2017").sheet1

# Extract and print all of the values
list_of_hashes = sheet.get_all_records()
print(list_of_hashes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17388/1354382564.py in <module>
#       5 # use creds to create a client to interact with the Google Drive API
#       6 scope = ['https://spreadsheets.google.com/feeds']
# ----> 7 creds = ServiceAccountCredentials.from_json_keyfile_name('credentials.json', scope)
#       8 client = gspread.authorize(creds)
#       9
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\oauth2client\service_account.py in from_json_keyfile_name(cls, filename, scopes, token_uri, revoke_uri)
#     219         with open(filename, 'r') as file_obj:
#     220             client_credentials = json.load(file_obj)
# --> 221         return cls._from_parsed_json_keyfile(client_credentials, scopes,
#     222                                              token_uri=token_uri,
#     223                                              revoke_uri=revoke_uri)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\oauth2client\service_account.py in _from_parsed_json_keyfile(cls, keyfile_dict, scopes, token_uri, revoke_uri)
#     169         creds_type = keyfile_dict.get('type')
#     170         if creds_type != client.SERVICE_ACCOUNT:
# --> 171             raise ValueError('Unexpected credentials type', creds_type,
#     172                              'Expected', client.SERVICE_ACCOUNT)
#     173
#
# ValueError: ('Unexpected credentials type', None, 'Expected', 'service_account')

# %%
from __future__ import print_function

import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# If modifying these scopes, delete the file token.json.
SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly']

# The ID and range of a sample spreadsheet.
SAMPLE_SPREADSHEET_ID = '1Us0KIsaerXgh7EP0oE6ryXZInJ1g-zbRlTX8OI8mehs'
SAMPLE_RANGE_NAME = 'A:N'


#def main():
"""Shows basic usage of the Sheets API.
Prints values from a sample spreadsheet.
"""
creds = None
# The file token.json stores the user's access and refresh tokens, and is
# created automatically when the authorization flow completes for the first
# time.
if os.path.exists('token.json'):
    creds = Credentials.from_authorized_user_file('token.json', SCOPES)
# If there are no (valid) credentials available, let the user log in.
if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
        creds.refresh(Request())
    else:
        flow = InstalledAppFlow.from_client_secrets_file(
            'credentials.json', SCOPES)
        creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open('token.json', 'w') as token:
        token.write(creds.to_json())

try:
    service = build('sheets', 'v4', credentials=creds)

    # Call the Sheets API
    sheet = service.spreadsheets()
    result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                range=SAMPLE_RANGE_NAME).execute()
    values = result.get('values', [])

    if not values:
        print('No data found.')
#        return

    #print('Name, Major:')
    for row in values:
        # Print columns A and E, which correspond to indices 0 and 4.
        print('%s, %s,%s, %s,%s, %s,%s, %s,%s, %s,%s' % (row[0], row[1], row[2], row[3], row[4], row[5], row[6], row[7], row[8], row[9], row[10]))
except HttpError as err:
    print(err)


#if __name__ == '__main__':
#    main()
# Out:
# Número do REDS, Tipo de Relatório,Data/Hora de Criação do Registro, Data/Hora do Fato,Natureza Principal, Endereço do Fato,DATA, HORA,N INI, N FIN,LOGRADOURO
# 2022-009777160-001, POLICIAL,3/5/22 8:19, 3/5/22 8:18,FURTO C01155 , AVENIDA FREI GABRIEL  /  - PARQUE DO TABOAO - CARMO DO PARANAIBA,05/03/sábado, 08:18:00,26, 45,AVENIDA FREI GABRIEL
# 2022-009970735-001, POLICIAL,3/6/22 21:50, 3/6/22 21:49,FURTO C01155 , RUA GIORDANO  /  - BELA VISTA - CARMO DO PARANAIBA,06/03/domingo, 21:49:00,18, 31,RUA GIORDANO
# 2022-009840613-001, POLICIAL,3/5/22 19:11, 3/5/22 19:11,FURTO C01155 , RUA PADRE MANOEL  /  - ROSARIO - CARMO DO PARANAIBA,05/03/sábado, 19:11:00,22, 32,RUA PADRE MANOEL
# 2022-010400086-001, POLICIAL,3/9/22 17:34, 3/8/22 22:00,FURTO C01155 , RUA JOAO FUNCHAL  /  - BOA ESPERANCA - SAO GOTARDO,08/03/terça-feira, 22:00:00,22, 38,RUA JOAO FUNCHAL
# 2022-010122648-001, POLICIAL,3/7/22 20:33, 3/7/22 20:33,FURTO RECEPTACAO C01155 C01180 , RUA JOAO FUNCHAL  /  - BOA ESPERANCA - SAO GOTARDO,07/03/segunda-feira, 20:33:00,22, 38,RUA JOAO FUNCHAL
# 2022-010049070-001, POLICIAL,3/7/22 13:40, 3/7/22 10:00,FURTO C01155 , FAZENDA TRO1215  /  - null - TIROS,07/03/segunda-feira, 10:00:00,21, 28,FAZENDA TRO1215
# 2022-010109861-001, POLICIAL,3/7/22 18:55, 3/4/22 15:00,FURTO C01155 , FAZENDA TRO1066  /  - null - TIROS,04/03/sexta-feira, 15:00:00,21, 28,FAZENDA TRO1066

# %%
values[4]
# Out:
# ['2022-010314932-001',
#  'POLICIAL',
#  '3/9/22 7:14',
#  '3/9/22 5:30',
#  'FURTO C01155 ',
#  'RUA PREFEITO ISMAEL FURTADO  /  - CENTRO - CARMO DO PARANAIBA',
#  '09/03/quarta-feira',
#  '05:30:00',
#  '33',
#  '42',
#  'RUA PREFEITO ISMAEL FURTADO',
#  'CENTRO',
#  'CARMO DO PARANAIBA',
#  '90']

# %%
import pandas as pd
dicionario = pd.DataFrame.from_dict(values)
dicionario.head()
# Out:
#                    0                  1                                 2   \
# 0      Número do REDS  Tipo de Relatório  Data/Hora de Criação do Registro
# 1  2022-009777160-001           POLICIAL                       3/5/22 8:19
# 2  2022-009970735-001           POLICIAL                      3/6/22 21:50
# 3  2022-009840613-001           POLICIAL                      3/5/22 19:11
# 4  2022-010314932-001           POLICIAL                       3/9/22 7:14
#
#                   3                   4   \
# 0  Data/Hora do Fato  Natureza Principal
# 1        3/5/22 8:18       FURTO C01155
# 2       3/6/22 21:49       FURTO C01155
# 3       3/5/22 19:11       FURTO C01155
# 4        3/9/22 5:30       FURTO C01155
#
#                                                   5                   6   \
# 0                                   Endereço do Fato                DATA
# 1  AVENIDA FREI GABRIEL  /  - PARQUE DO TABOAO - ...        05/03/sábado
# 2  RUA GIORDANO  /  - BELA VISTA - CARMO DO PARAN...       06/03/domingo
# 3  RUA PADRE MANOEL  /  - ROSARIO - CARMO DO PARA...        05/03/sábado
# 4  RUA PREFEITO ISMAEL FURTADO  /  - CENTRO - CAR...  09/03/quarta-feira
#
#          7      8      9                            10                11  \
# 0      HORA  N INI  N FIN                   LOGRADOURO            BAIRRO
# 1  08:18:00     26     45         AVENIDA FREI GABRIEL  PARQUE DO TABOAO
# 2  21:49:00     18     31                 RUA GIORDANO        BELA VISTA
# 3  19:11:00     22     32             RUA PADRE MANOEL           ROSARIO
# 4  05:30:00     33     42  RUA PREFEITO ISMAEL FURTADO            CENTRO
#
#                    12   13
# 0           MUNICÍPIO  CIA
# 1  CARMO DO PARANAIBA   90
# 2  CARMO DO PARANAIBA   90
# 3  CARMO DO PARANAIBA   90
# 4  CARMO DO PARANAIBA   90
