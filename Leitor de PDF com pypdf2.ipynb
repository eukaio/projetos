# %%
from PyPDF2 import PdfFileReader
def get_info(path):
    with open(path, 'rb') as f:
        pdf = PdfFileReader(f)
        info = pdf.getDocumentInfo()
        number_of_pages = pdf.getNumPages()
    
    print(info)
    print(pdf)
    author = info.author
    creator = info.creator
    producer = info.producer
    subject = info.subject
    title = info.title
if __name__ == '__main__':
    path = r'C:\Users\kainu\Downloads\teste.pdf'
    get_info(path)
# Out:
# {'/Author': 'kaio Gonçalves', '/Creator': 'Microsoft® Word 2016', '/CreationDate': "D:20220313141430-03'00'", '/ModDate': "D:20220313141430-03'00'", '/Producer': 'Microsoft® Word 2016'}
# <PyPDF2.pdf.PdfFileReader object at 0x000001E5DF5B0F10>

# %%
import PyPDF2

pdffile= open(r'C:\Users\kainu\Downloads\teste.pdf', 'rb')

pdf = PyPDF2.PdfFileReader(pdffile)

print(pdf.isEncrypted)

#pdfreader.decrypt('')
information = pdf.getDocumentInfo()
number_of_pages = pdf.getNumPages()

print(information)
# Out:
# False
# {'/Author': 'kaio Gonçalves', '/Creator': 'Microsoft® Word 2016', '/CreationDate': "D:20220313141430-03'00'", '/ModDate': "D:20220313141430-03'00'", '/Producer': 'Microsoft® Word 2016'}
